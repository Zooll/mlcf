# %%
import os

# %%
PATH1 = 'blood-pressure-estimation-data/data_test1_blank'
PATH2 = 'blood-pressure-estimation-data/data_test2_blank'

# %%
lst = os.listdir(PATH2)
v = zip(lst, [113] * len(lst), [65] * len(lst))
for x in v:
    print(x[0], x[1], x[2], sep=',')
# Out:
# subj17log1116.csv,113,65
# subj28log1889.csv,113,65
# subj31log2063.csv,113,65
# subj24log1515.csv,113,65
# subj28log1836.csv,113,65
# subj24log1555.csv,113,65
# subj24log1554.csv,113,65
# subj31log2100.csv,113,65
# subj20log1249.csv,113,65
# subj31log2112.csv,113,65
# subj17log1118.csv,113,65
# subj23log1494.csv,113,65
# subj20log1215.csv,113,65
# subj20log1226.csv,113,65
# subj23log1459.csv,113,65
# subj28log1868.csv,113,65
# subj23log1496.csv,113,65
# subj20log1221.csv,113,65
# subj1log63.csv,113,65
# subj31log2057.csv,113,65
# subj17log1099.csv,113,65
# subj20log1288.csv,113,65
# subj23log1479.csv,113,65
# subj31log2105.csv,113,65
# subj20log1283.csv,113,65
# subj24log1514.csv,113,65
# subj24log1552.csv,113,65
# subj20log1256.csv,113,65
# subj24log1539.csv,113,65
# subj1log50.csv,113,65
# subj28log1827.csv,113,65
# subj31log2114.csv,113,65
# subj20log1237.csv,113,65
# subj1log46.csv,113,65
# subj24log1517.csv,113,65
# subj1log54.csv,113,65
# subj28log1860.csv,113,65
# ...
